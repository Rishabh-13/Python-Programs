# %%
from PIL import Image

# %%
#input Image in png format

im = Image.open("spiderman.png")
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=360x326 at 0x29DDF654F70>

# %%
rgb_im = im.convert('RGB')

# %%
#output Image in Jpeg format
rgb_im.save('spiderman.jpg')
